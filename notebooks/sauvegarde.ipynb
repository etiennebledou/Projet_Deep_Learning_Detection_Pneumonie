# %%
# ============================================================
# SECTION 14 : SAUVEGARDE FINALE
# ============================================================

import os

print("Sauvegarde des modeles entraines...")

# Sauvegarder tous les modeles
modeles_a_sauver = [
    (model1,    "model1_cnn_baseline.pth"),
    (model2,    "model2_resnet18.pth"),
    (model3,    "model3_densenet121.pth"),
    (model4,    "model4_efficientnet_v2.pth"),
    (model5,    "model5_cnn_vit.pth"),
    (model5_ft, "model5_cnn_vit_finetuned_optuna.pth"),  
]

for model_ref, nom_fichier in modeles_a_sauver:
    torch.save(model_ref.state_dict(), nom_fichier)
    taille = os.path.getsize(nom_fichier) / 1e6
    print(f"  {nom_fichier:<45} ({taille:.1f} MB)")
